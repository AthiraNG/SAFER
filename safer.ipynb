# %%
pip install earthengine-api
# Out:
# Requirement already satisfied: earthengine-api in c:\users\athira\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: google-cloud-storage in c:\users\athira\anaconda3\lib\site-packages (from earthengine-api) (2.19.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\athira\anaconda3\lib\site-packages (from earthengine-api) (2.154.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\athira\anaconda3\lib\site-packages (from earthengine-api) (2.36.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\athira\anaconda3\lib\site-packages (from earthengine-api) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\athira\anaconda3\lib\site-packages (from earthengine-api) (0.22.0)
# Requirement already satisfied: requests in c:\users\athira\anaconda3\lib\site-packages (from earthengine-api) (2.31.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\athira\anaconda3\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (2.23.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\athira\anaconda3\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\athira\anaconda3\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\athira\anaconda3\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\athira\anaconda3\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\athira\anaconda3\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.0.9)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\athira\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in c:\users\athira\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\athira\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\athira\anaconda3\lib\site-packages (from requests->earthengine-api) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\athira\anaconda3\lib\site-packages (from requests->earthengine-api) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\athira\anaconda3\lib\site-packages (from requests->earthengine-api) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\athira\anaconda3\lib\site-packages (from requests->earthengine-api) (2023.7.22)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\athira\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.66.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\users\athira\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (5.29.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\athira\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.25.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\athira\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geemap
# Out:
# Requirement already satisfied: geemap in c:\users\athira\anaconda3\lib\site-packages (0.35.1)
# Requirement already satisfied: bqplot in c:\users\athira\anaconda3\lib\site-packages (from geemap) (0.12.43)
# Requirement already satisfied: colour in c:\users\athira\anaconda3\lib\site-packages (from geemap) (0.1.5)
# Requirement already satisfied: earthengine-api>=1.0.0 in c:\users\athira\anaconda3\lib\site-packages (from geemap) (1.4.2)
# Requirement already satisfied: eerepr>=0.0.4 in c:\users\athira\anaconda3\lib\site-packages (from geemap) (0.0.4)
# Requirement already satisfied: folium>=0.17.0 in c:\users\athira\anaconda3\lib\site-packages (from geemap) (0.18.0)
# Requirement already satisfied: geocoder in c:\users\athira\anaconda3\lib\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in c:\users\athira\anaconda3\lib\site-packages (from geemap) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\athira\anaconda3\lib\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.19.2 in c:\users\athira\anaconda3\lib\site-packages (from geemap) (0.19.2)
# Requirement already satisfied: ipytree in c:\users\athira\anaconda3\lib\site-packages (from geemap) (0.2.2)
# Requirement already satisfied: matplotlib in c:\users\athira\anaconda3\lib\site-packages (from geemap) (3.7.2)
# Requirement already satisfied: numpy in c:\users\athira\anaconda3\lib\site-packages (from geemap) (1.24.3)
# Requirement already satisfied: pandas in c:\users\athira\anaconda3\lib\site-packages (from geemap) (2.0.3)
# Requirement already satisfied: plotly in c:\users\athira\anaconda3\lib\site-packages (from geemap) (5.9.0)
# Requirement already satisfied: pyperclip in c:\users\athira\anaconda3\lib\site-packages (from geemap) (1.9.0)
# Requirement already satisfied: pyshp>=2.3.1 in c:\users\athira\anaconda3\lib\site-packages (from geemap) (2.3.1)
# Requirement already satisfied: python-box in c:\users\athira\anaconda3\lib\site-packages (from geemap) (7.2.0)
# Requirement already satisfied: scooby in c:\users\athira\anaconda3\lib\site-packages (from geemap) (0.10.0)
# Requirement already satisfied: google-cloud-storage in c:\users\athira\anaconda3\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.19.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\athira\anaconda3\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.154.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\athira\anaconda3\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.36.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\athira\anaconda3\lib\site-packages (from earthengine-api>=1.0.0->geemap) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\athira\anaconda3\lib\site-packages (from earthengine-api>=1.0.0->geemap) (0.22.0)
# Requirement already satisfied: requests in c:\users\athira\anaconda3\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.31.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\athira\anaconda3\lib\site-packages (from folium>=0.17.0->geemap) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\athira\anaconda3\lib\site-packages (from folium>=0.17.0->geemap) (3.1.2)
# Requirement already satisfied: xyzservices in c:\users\athira\anaconda3\lib\site-packages (from folium>=0.17.0->geemap) (2022.9.0)
# Requirement already satisfied: ipywidgets in c:\users\athira\anaconda3\lib\site-packages (from ipyfilechooser>=0.6.0->geemap) (8.0.4)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in c:\users\athira\anaconda3\lib\site-packages (from ipyleaflet>=0.19.2->geemap) (0.19.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\athira\anaconda3\lib\site-packages (from ipyleaflet>=0.19.2->geemap) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\athira\anaconda3\lib\site-packages (from bqplot->geemap) (5.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\athira\anaconda3\lib\site-packages (from pandas->geemap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\athira\anaconda3\lib\site-packages (from pandas->geemap) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\athira\anaconda3\lib\site-packages (from pandas->geemap) (2023.3)
# Requirement already satisfied: click in c:\users\athira\anaconda3\lib\site-packages (from geocoder->geemap) (8.0.4)
# Requirement already satisfied: future in c:\users\athira\anaconda3\lib\site-packages (from geocoder->geemap) (0.18.3)
# Requirement already satisfied: ratelim in c:\users\athira\anaconda3\lib\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: six in c:\users\athira\anaconda3\lib\site-packages (from geocoder->geemap) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\athira\anaconda3\lib\site-packages (from matplotlib->geemap) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\athira\anaconda3\lib\site-packages (from matplotlib->geemap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\athira\anaconda3\lib\site-packages (from matplotlib->geemap) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\athira\anaconda3\lib\site-packages (from matplotlib->geemap) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\athira\anaconda3\lib\site-packages (from matplotlib->geemap) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\athira\anaconda3\lib\site-packages (from matplotlib->geemap) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\athira\anaconda3\lib\site-packages (from matplotlib->geemap) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\athira\anaconda3\lib\site-packages (from plotly->geemap) (8.2.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\athira\anaconda3\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (2.23.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\athira\anaconda3\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\athira\anaconda3\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\athira\anaconda3\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\athira\anaconda3\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (4.9)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\athira\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.25.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\athira\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.15.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\athira\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\athira\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\athira\anaconda3\lib\site-packages (from jinja2>=2.9->folium>=0.17.0->geemap) (2.1.1)
# Requirement already satisfied: colorama in c:\users\athira\anaconda3\lib\site-packages (from click->geocoder->geemap) (0.4.6)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\athira\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in c:\users\athira\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\athira\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\athira\anaconda3\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\athira\anaconda3\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\athira\anaconda3\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\athira\anaconda3\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (2023.7.22)
# Requirement already satisfied: decorator in c:\users\athira\anaconda3\lib\site-packages (from ratelim->geocoder->geemap) (5.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\athira\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (1.66.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\users\athira\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (5.29.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\athira\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (1.25.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\athira\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\athira\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\athira\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\athira\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\athira\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\athira\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.5.6)
# Requirement already satisfied: psutil in c:\users\athira\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\athira\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\athira\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.3.2)
# Requirement already satisfied: backcall in c:\users\athira\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\athira\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\athira\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\athira\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\athira\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\athira\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\athira\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (0.4.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\athira\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\athira\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\athira\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\athira\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (305.1)
# Requirement already satisfied: wcwidth in c:\users\athira\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.5)
# Requirement already satisfied: executing in c:\users\athira\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\athira\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\athira\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install datetime
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Requirement already satisfied: datetime in c:\users\athira\anaconda3\lib\site-packages (5.5)
# Requirement already satisfied: zope.interface in c:\users\athira\anaconda3\lib\site-packages (from datetime) (5.4.0)
# Requirement already satisfied: pytz in c:\users\athira\anaconda3\lib\site-packages (from datetime) (2023.3.post1)
# Requirement already satisfied: setuptools in c:\users\athira\anaconda3\lib\site-packages (from zope.interface->datetime) (68.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ee
import geemap
import math
from datetime import datetime
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ee.Authenticate()
ee.Initialize()
Map = geemap.Map()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Constants
gsc = ee.Number(0.0820) # solar constant MJ/m2
# Regression constant, intercept, expressing the fraction of extra-terrestrial radiation reaching the earth on overcast days
As = ee.Number(0.23)
Bs = ee.Number(0.5)


# Define the year and month
year = 2010
month = 2 

# Define start and end dates
start_date = ee.Date.fromYMD(year, month, 1)  # First day of the month
end_date = start_date.advance(1, 'month')    # Advance by one month

# Date of Year (DOY)
j = datetime(year, month, day).timetuple().tm_yday 



# Define region of interest (roi)
roi = ee.FeatureCollection('projects/ee-athiraganesan314/assets/Shivalik_range')

# Define roi for sampling 
aoi_minmax = ee.FeatureCollection('users/athiraganesan314/aoi_minmax')

# Tower location for Sampling
pts = ee.FeatureCollection('projects/ee-athiraganesan314/assets/tower_locations')

Map.centerObject(roi,12)
Map.addLayer(roi,{},"roi")

# radians
lonlat = ee.Image.pixelLonLat().clip(roi);
radians = lonlat.expression('(b(1) * 3.141592653589793) / 180', 
{'b': lonlat.select(['latitude'])});

# Load and process MODIS LST data
lst = (ee.ImageCollection('MODIS/061/MOD11A1')
       .filterDate(start_date, end_date)
       .filterBounds(roi)
       .select('LST_Day_1km')
       .mean()
       .clip(roi)
       .multiply(0.02))  # Convert to Celsius

# Load and process NDVI data
ndvi = (ee.ImageCollection('MODIS/061/MOD13A1')
        .filterDate(start_date, end_date)
        .filterBounds(roi)
        .select('NDVI')
        .median()
        .clip(roi)
        .multiply(0.0001))  # Scale factor

# Load and process ERA5 wind data
wind = (ee.ImageCollection('ECMWF/ERA5_LAND/HOURLY')
        .filterDate(start_date, end_date)
        .filterBounds(roi)
        .select(['u_component_of_wind_10m', 'v_component_of_wind_10m'])
        .first()
        .clip(roi))

# Surface reflectance dataset and albedo calculation
dataset = (ee.ImageCollection('MODIS/061/MOD09GA')
           .filterDate(start_date, end_date)
           .filterBounds(roi))
bands_alb = (dataset.select(['sur_refl_b01', 'sur_refl_b02'])
             .mean()
             .multiply(0.0001)
             .clip(roi))
alb = bands_alb.expression(
    '0.08 + (0.41 * RED) + (0.14 * NIR)', {
        'NIR': bands_alb.select('sur_refl_b02'),
        'RED': bands_alb.select('sur_refl_b01')
    })

# Load and process Temp data
temp = (ee.ImageCollection('ECMWF/ERA5_LAND/HOURLY')
        .filterDate(start_date, end_date)
        .filterBounds(roi)
        .select('temperature_2m')
        .first()
        .clip(roi))

# Load and process elevation data
z = (ee.Image('USGS/SRTMGL1_003')
        .select('elevation')
        .clip(roi));

# Sample Min and Max Temperature 
temp_minmax = temp.reduceRegions(
collection = aoi_minmax,
reducer = ee.Reducer.minMax()
)
stack=wind.addBands(alb) 
sampled= stack.sampleRegions(
  collection = pts,
  properties = ['point'],
  scale = 9000,
  geometries = True
  
)

# Extract the values of some environmental variable(wind,albedo,temperature)
mete_values = ee.FeatureCollection([sampled,temp_minmax]).flatten()

uwind= mete_values.aggregate_mean('u_component_of_wind_10m')
vwind= mete_values.aggregate_mean('v_component_of_wind_10m')
dew= mete_values.aggregate_mean('dewpoint_temperature_2m')
alb= mete_values.aggregate_mean('constant')
tmax= mete_values.aggregate_mean('max')
tmin= mete_values.aggregate_mean('min')

# Functions for calculating atmospheric and environmental variable for the calculation of ETo and ETa

def calculate_kc(lst, ndvi, alb):
    return lst.subtract(273.15).divide(ndvi.multiply(alb)).multiply(-0.008).add(1.8).exp()

def calculate_tmean(tmin, tmax):
    return (tmin.add(tmax)).divide(2)

def calculate_uh(uwind, vwind):
    return ((uwind.pow(2)).add(vwind.pow(2))).sqrt()

def calculate_u2(uh):
    return uh.multiply(0.7479511)

def calculate_ssvp(tmean):
    return ((((((tmean.subtract(273.15)).multiply(17.27)).divide(((tmean.subtract(273.15)).add(237.3)))).exp())
             .multiply(0.6108)).multiply(4098)).divide((((tmean.subtract(273.15)).add(237.3)).pow(2)))

def calculate_p(z):
    return ((((ee.Number(293)).subtract(z.multiply(0.0065))).divide(ee.Number(293))).pow(ee.Number(5.26))).multiply(101.3)

def calculate_r(p):
    return p.multiply(0.000665)

def calculate_etmax(tmax):
    return tmax.subtract(273.15).multiply(17.27).divide(
        tmax.subtract(273.15).add(237.3)
    ).exp().multiply(0.6108)

def calculate_etmin(tmin):
    return tmin.subtract(273.15).multiply(17.27).divide(
        tmin.subtract(273.15).add(237.3)
    ).exp().multiply(0.6108)  

def calculate_ea(tmin):
    return tmin.subtract(273.15).multiply(17.27).divide(
        tmin.subtract(273.15).add(237.3)
    ).exp().multiply(0.6108)


def calculate_es(etmax, etmin):
    return (etmax.add(etmin)).divide(2)

def calculate_dr(j):
    return (((ee.Number(((math.pi*2)/365)*j)).cos()).multiply(0.033)).add(1)

def calculate_sd(j):
    return (ee.Number((((math.pi*2)/365)*j)-(1.39)).sin()).multiply(0.409)

def calculate_ws(radians):
    return ((((radians).multiply(-1)).tan()).multiply(sd.tan())).acos()

def calculate_Ra(ws, radians, sd, gsc, dr):
    return ((ws.multiply(ee.Number(radians).sin()).multiply(sd.sin())).add((ee.Number(radians).cos()).multiply(sd.cos()).multiply(ws.sin()))).multiply(dr).multiply(gsc).multiply(1440/(math.pi))

def calculate_Rso(Ra):
    return Ra.multiply(0.759)

def calculate_N(ws):
    return (ee.Number(24).divide(math.pi)).multiply(ws)

def calculate_n(tmean):
    return tmean.subtract(273.15).multiply(0.232).add(4.352)

def calculate_Rs(n, N, As, Bs, Ra):
    return (ee.Number(n.divide(N))).multiply(Bs).add(As.multiply(Ra))

def calculate_Rns(alb, Rs):
    return ((ee.Number(1)).subtract(alb)).multiply(Rs)

def calculate_Rnl(tmax, tmin, ea, Rs, Rso):
    return ((((((tmax.subtract(273.15)).add(273.16)).pow(4)).add(((tmin.subtract(273.15)).add(273.16)).pow(4))).divide(2)).multiply(0.000000004903)).multiply(ee.Number(0.34).subtract((ea.sqrt().multiply(0.14)))).multiply(ee.Number(1.35).multiply(Rs.divide(Rso)).subtract(0.35))

def calculate_Rn(Rns, Rnl):
    return Rns.subtract(Rnl)

def calculate_ETo(Rn, ssvp, tmean, u2, r, ea, es):
        # Convert mean temperature to Celsius
    tmean_celsius = tmean.subtract(273.15)

    # First term
    term1 = ee.Number(0.408).multiply(Rn).multiply(ssvp).divide(
        u2.multiply(0.34).add(1).multiply(r).add(ssvp)
    )

    # Second term
    term2 = ee.Number(900).divide(tmean_celsius.add(273)).multiply(u2).multiply(
        es.subtract(ea)
    ).multiply(r).divide(
        u2.multiply(0.34).add(1).multiply(r).add(ssvp)
    )

    # Sum the terms
    return term1.add(term2)

   
def calculate_ETa(kc, ETo):
    return ETo.multiply(kc)


# Calculate crop coefficient (kc)
kc = calculate_kc(lst, ndvi, alb)

# Calculate other atmospheric and environmental variable for the calculation of ETo and ETa
tmean = calculate_tmean(tmin,tmax)
uh = calculate_uh(uwind, vwind)
u2 = calculate_u2(uh)
ssvp = calculate_ssvp(tmean)
p = calculate_p(z)
r = calculate_r(p)
etmax = calculate_etmax(tmax)
etmin = calculate_etmin(tmin)  
ea = calculate_ea(tmin)
es = calculate_es(etmax, etmin) 
dr = calculate_dr(j)
sd = calculate_sd(j)
ws = calculate_ws(radians)
Ra = calculate_Ra(ws, radians, sd, dr, gsc)
Rso = calculate_Rso(Ra)
N = calculate_N(ws)
n = calculate_n(tmean)
Rs = calculate_Rs(n, N, Bs, As, Ra)
Rns = calculate_Rns(alb, Rs)
Rnl = calculate_Rnl(tmax, tmin, ea, Rs, Rso)
Rn = calculate_Rn(Rns, Rnl)

# Reference Evapotranspiration (FAO 56)
ETo = calculate_ETo(Rn, ssvp, tmean, u2, r, ea, es)


# Actual Evapotranspiration
ETa = (kc, ETo)


Map.addLayer(ETa,{},"ETo")
display(Map)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(bottom=859387.0, center=[30.84969750340992, 77.24333304891434], controls=(WidgetControl(options=['position…
